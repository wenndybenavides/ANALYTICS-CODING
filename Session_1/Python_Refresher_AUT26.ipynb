# %% [markdown]
# # Session 1.1 : Python Refresher
#
# _Analytics Through Coding Autumn 2026_
#
# ---
#
# You have already covered the fundamentals of Python during the pre-course preparation.
# Rather than starting again from the beginning, we will use this notebook to **refresh the core concepts that we will need for data analysis**.
#
# We will revisit calculations, variables, data types, functions, comparisons, conditional statements and loops through a series of short examples and exercises.
#
# ---

# %% [markdown]
# ## Starting out
#
# This session assumes that you have:
#
# * Opened the GitHub Codespace for Session 1.
#
# If you haven't already, you should open the Codespace before starting the session.
#
# In this session, we'll work through a series of small Python refresher exercises.
#
# * I encourage you to chat with your colleagues and work together on the exercises.
# * Don't worry if you cannot remember every piece of syntax immediately — the aim is to refresh what you have already seen.
#
# ### Submission
#
# There is no submission required for exercises covered in sessions. The exercises are designed to prepare you for the analytical work later in the course.
#
# ### GitHub Codespaces
#
# Codespaces are a cloud-based environment for coding, provided by GitHub. The Codespace gives us access to a prepared coding environment without having to install Python locally.
#
# Files are saved automatically in the Codespace, as long as you have an active internet connection.
#
# ![GitHub Codespaces](codespace.png)

# %% [markdown]
# ## Expressions, calculations and variables
#
# Python can be used as a calculator, but the more useful idea is that we can **store the results of calculations in variables** and reuse them later.
#
# Let's begin with a quick example.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Refresher.</b>
# A variable gives a name to a value. Python first evaluates the expression on the right-hand side of <code>=</code> and then stores the result using the variable name on the left.
# </div>

# %% [markdown]
# ### Your turn
#
# A business sells 125 units of a product for £18.50 each. The cost of producing each unit is £11.20.
#
# Using Python:
#
# 1. Create variables for the quantity, selling price and unit cost.
# 2. Calculate total revenue.
# 3. Calculate total cost.
# 4. Calculate profit.
#
# Use meaningful variable names.

# %%
# Write your code here

# %% [markdown]
# ## Objects, types and errors
#
# Python objects have different **types**. The type determines what Python can do with the object.
#
# Let's remind ourselves of a few common types.

# %% [markdown]
# What happens if we try to combine incompatible types?

# %% [markdown]
# <div class="alert alert-warning">
# <b>Note.</b> Error messages are useful. They tell us the type of error and usually point us towards the line where the problem occurred. As our analysis becomes more complex, being able to read an error message becomes an important analytical skill.
# </div>

# %% [markdown]
# ### Your turn: fix the error
#
# The code below is intended to calculate profit, but it does not work.
#
# Run the code, inspect the error message and fix the problem.

# %%
revenue = "2500"
cost = 1750

profit = revenue - cost

# %% [markdown]
# ## Strings and displaying output
#
# Strings are sequences of text. We normally create them using quotation marks.
#
# The built-in `print()` function allows us to display values and messages.

# %% [markdown]
# We can also combine text and values using **f-strings**.

# %% [markdown]
# ### Your turn
#
# Create variables called `company`, `revenue` and `profit`.
#
# Print a sentence in the following format:
#
# `Company A generated £5000 revenue and £1200 profit.`
#
# Use an f-string rather than typing the values directly into the sentence.

# %%
# Write your code here

# %% [markdown]
# ## Built-in functions
#
# Python includes many useful built-in functions. You have already seen `print()` and `type()`.
#
# Other common functions include:

# %% [markdown]
# Functions take one or more **arguments** and return a result. We will use functions constantly throughout the course, particularly when working with pandas.

# %% [markdown]
# ### Your turn
#
# Suppose the sales figures for three stores are:
#
# * Store A: 1240
# * Store B: 980
# * Store C: 1560
#
# Use Python functions to find:
#
# 1. The highest sales figure.
# 2. The lowest sales figure.
# 3. The difference between the highest and lowest sales figures.

# %%
# Write your code here

# %% [markdown]
# ## Comparisons and Boolean values
#
# Analytical work often involves asking whether a condition is true or false.
#
# Python comparisons return a Boolean value: `True` or `False`.

# %% [markdown]
# Boolean expressions can be combined using `and`, `or` and `not`.

# %% [markdown]
# ## Conditional statements
#
# Conditional statements allow our programs to make decisions based on the data.

# %% [markdown]
# <div class="alert alert-warning">
# <b>Syntax note.</b>
# When writing an <code>if</code> statement:
# <ul>
# <li>The condition is followed by a colon <code>:</code>.</li>
# <li>The code that belongs to the condition must be indented.</li>
# <li>Python normally uses four spaces for indentation.</li>
# </ul>
# </div>

# %% [markdown]
# ### Your turn
#
# A company classifies an order as:
#
# * `"High value"` if the order is greater than £1,000.
# * `"Medium value"` if the order is between £500 and £1,000.
# * `"Standard value"` otherwise.
#
# Use `if`, `elif` and `else` to classify the order below.

# %%
order_value = 750

# Write your code below

# %% [markdown]
# ## Iteration using loops
#
# Sometimes we need to repeat the same operation for several values.
#
# A `for` loop allows us to iterate over a sequence of values.

# %% [markdown]
# We can also perform a calculation during each iteration.

# %% [markdown]
# ### Your turn
#
# The list below contains monthly sales figures.
#
# For each value:
#
# * print the sales figure;
# * if the sales figure is greater than 1,000, also print `"Target achieved"`.

# %%
monthly_sales = [850, 1200, 975, 1400, 1100]

# %% [markdown]
# ## Putting it together
#
# Let's finish with a short problem that combines several of the ideas we have refreshed.
#
# A retailer records the following information for an order:
#
# * Unit price: £35
# * Quantity: 40
# * Unit cost: £21
# * Discount: 10%
#
# Write Python code that:
#
# 1. Stores the information in appropriately named variables.
# 2. Calculates the revenue before the discount.
# 3. Calculates the revenue after the discount.
# 4. Calculates the total cost.
# 5. Calculates the final profit.
# 6. Prints the final profit.
# 7. Prints `"Profitable order"` if the final profit is greater than zero and `"Loss-making order"` otherwise.

# %%
# Write your code here

# %% [markdown]
# ## All done!
#
# That's the end of our Python refresher.
#
# The important point is not to memorise every piece of syntax. You should be comfortable with the basic building blocks and, importantly, be able to recognise what Python code is doing and diagnose simple problems.
#
# We will now move from general Python to **pandas**, where we will use these ideas to work with tabular datasets.
#
# ---
#
# ## Syntax roundup
#
# We have refreshed:
#
# * calculations and assignment;
# * variables and data types;
# * strings and displaying output;
# * built-in functions;
# * comparisons and Boolean values;
# * conditional statements;
# * `for` loops;
# * reading and fixing simple errors.
#
# These concepts will appear throughout the rest of the course.

# %% [markdown]
# ## [EXTRA] Expressions and calculations
#
# Computer programs consist of _expressions_, which tell the computer how to combine pieces of data. One common example are numerical expressions. For example, `5` is a simple numerical expression with just a single piece of data, and `2 + 3` is an addition expression that combines the data `2` and `3` using the `+` symbol.
#
# In Python, we can enter calculations directly into the console and it will display the answer. When we do so and write `2 + 3`, Python _evaluates_ this expression, and gives us the result.
#
# Let's try this out in the console. Enter each of the following commands, one at a time. Type in or copy the command, hit return, and see what happens.

# %% [markdown]
# The common arithmetic operations in Python are as follows.
#
# | Operator     | Name           | Description                                            |
# |--------------|----------------|--------------------------------------------------------|
# | ``a + b``    | Addition       | Sum of ``a`` and ``b``                                 |
# | ``a - b``    | Subtraction    | Difference of ``a`` and ``b``                          |
# | ``a * b``    | Multiplication | Product of ``a`` and ``b``                             |
# | ``a / b``    | Division  | Quotient of ``a`` and ``b``                            |
# | ``a // b``   | Floor division | Quotient of ``a`` and ``b``, removing fractional parts |
# | ``a % b``    | Modulus        | Remainder after division of ``a`` by ``b``     |
# | ``a ** b``   | Exponentiation | ``a`` to the power of ``b``                     |
#
# What would you expect the following commands do? Check your intuition with the console.
